# %%
from nilearn import plotting
from nipype import Workflow, Node
from interfaces.Reslicing import Reslicing
from interfaces.Denoise import Denoise
from nipype.interfaces.fsl import (BET, ExtractROI, FAST, FLIRT, MCFLIRT, SliceTimer, Threshold)

# %%
t1_input_file = '/home/brainlab/Desktop/Rudas/Data/hcp_100/899885_3T_Diffusion_preproc/data/T1w/T1w_acpc_dc_restore_1.25.nii.gz'

# %%
bet_t1 = Node(BET(frac=0.5, robust=True, mask=True, output_type='NIFTI_GZ'), name="bet_t1")

# %%
denoise_t1 = Node(Denoise(), name="denoising_t1") # Dipy

# %%
denoise_t1.inputs.in_file = t1_input_file
denoise_t1.run()
# Out:
# 190620-11:55:47,775 nipype.workflow INFO:
# 	 [Node] Setting-up "denoising_t1" in "/tmp/tmpulc4g6ls/denoising_t1".
# 190620-11:55:47,779 nipype.workflow INFO:
# 	 [Node] Running "denoising_t1" ("interfaces.Denoise.Denoise")
# 190620-11:56:24,729 nipype.workflow INFO:
# 	 [Node] Finished "denoising_t1".

# %% [markdown]
# Before noising remotion

# %%
plotting.plot_anat(t1_input_file)

# %% [markdown]
# After noising remotion

# %%
plotting.plot_anat('/tmp/tmpulc4g6ls/denoising_t1/denoised.nii.gz')
